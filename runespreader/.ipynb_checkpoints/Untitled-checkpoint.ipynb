# %%
from runespreader.main import Runespreader
import pandas as pd
from clickhouse_driver import Client
import os
import time
import yaml
name = "Dragon bones"
config = yaml.load(open('/home/charles/.config/runespreader'), Loader=yaml.Loader)
client = Client(host='localhost', password=config.get("CH_PASSWORD"))
rs_live = client.execute(f"select * from rs_live_prices where name = '{name}'")
df = pd.DataFrame(rs_live, columns=['high', 'high_time', 'low','low_time','name','id'])

# %%
import plotly.express as px
import plotly.graph_objects as go
db_df = df[df["name"] == name]
fig = go.Figure()
high_db_df = db_df.sort_values(["high_time"], ascending=True)
low_db_df = db_df.sort_values(["low_time"], ascending=True)
fig.add_trace(go.Scatter(x=high_db_df["high_time"], y=high_db_df["high"],
                    mode='lines',
                    name='Buy top side'))
fig.add_trace(go.Scatter(x=low_db_df["low_time"], y=low_db_df["low"],
                    mode='lines',
                    name='Buy top side'))
fig.show()

# %%
high_db_df
# Out:
# Empty DataFrame
# Columns: [high, high_time, low, low_time, name, id]
# Index: []

# %%
df
# Out:
# Empty DataFrame
# Columns: [high, high_time, low, low_time, name, id]
# Index: []

# %%
from runespreader.main import Runespreader
import pandas as pd
from clickhouse_driver import Client
import os
import time
import yaml
import pandas as pd
config = yaml.load(open('/home/charles/.config/runespreader'), Loader=yaml.Loader)
profit_threshold = config.get("POTENTIAL_PROFIT")
def refresh_vol_list():
    r = Runespreader()
    v_data = r.get_volumes()
    timestamp = v_data["timestamp"]
    volumes = v_data["data"]
    symbols_to_track = []
    for uuid, volume in volumes.items():
        if volume >= int(config.get("DAILY_VOL_THRESHOLD")):
            symbols_to_track.append(r.get_name_for_id(uuid))
    return timestamp, symbols_to_track

timestamp, symbols_to_track = refresh_vol_list()
r = Runespreader()
deal_dict = {}
if timestamp - time.time() > 86400:
    timestamp, symbols_to_track = refresh_vol_list()
client = Client(host='localhost', password=config.get("CH_PASSWORD"))
rs_sells = client.execute(f"select low, lowTime, name, id from rs_sells where lowTime >= now() - interval 15 minute")
rs_buys = client.execute(f"select high, highTime, name, id from rs_buys where highTime >= now() - interval 15 minute")
high_df = pd.DataFrame(rs_buys, columns=['high', 'high_time', 'name','id']).sort_values(["high_time"], ascending=False)
low_df = pd.DataFrame(rs_sells, columns=['low', 'low_time', 'name','id']).sort_values(["low_time"], ascending=False)
for symbol in symbols_to_track:
    try:
        last_sell = low_df[low_df["name"] == symbol].iloc[0]
        last_buy = high_df[high_df["name"] == symbol].iloc[0]
    except:
        continue
    profit_per_item = (last_buy["high"] - (last_buy["high"] * .01)) - last_sell["low"]
    limit = r.name_to_limit.get(symbol)
    potential_profit = profit_per_item * limit
    if potential_profit >= profit_threshold:
        if deal_dict.get("symbol", time.time()) > time.time() - 300:
            
        print(last_sell, last_buy, symbol, profit_per_item, potential_profit)
# Out:
# low                        1111
# low_time    2023-08-12 19:22:20
# name          Irit potion (unf)
# id                          101
# Name: 629104, dtype: object high                        1200
# high_time    2023-08-12 19:23:30
# name           Irit potion (unf)
# id                           101
# Name: 355897, dtype: object Irit potion (unf) 77.0 770000.0
# low                            1275
# low_time        2023-08-12 19:22:00
# name        Dwarf weed potion (unf)
# id                              109
# Name: 617850, dtype: object high                            1324
# high_time        2023-08-12 19:20:32
# name         Dwarf weed potion (unf)
# id                               109
# Name: 89511, dtype: object Dwarf weed potion (unf) 35.75999999999999 357599.9999999999
# low                         300
# low_time    2023-08-12 19:24:12
# name              White berries
# id                          239
# Name: 723103, dtype: object high                         329
# high_time    2023-08-12 19:21:50
# name               White berries
# id                           239
# Name: 231236, dtype: object White berries 25.70999999999998 334229.9999999997
# low                       10827
# low_time    2023-08-12 19:24:30
# name                 Runite ore
# id                          451
# Name: 723452, dtype: object high                       11000
# high_time    2023-08-12 19:23:58
# name                  Runite ore
# id                           451
# Name: 356170, dtype: object Runite ore 63.0 283500.0
# low                        1935
# low_time    2023-08-12 19:24:35
# name               Dragon bones
# id                          536
# Name: 723618, dtype: object high                        2000
# high_time    2023-08-12 19:23:03
# name                Dragon bones
# id                           536
# Name: 345970, dtype: object Dragon bones 45.0 337500.0
# low                        1225
# low_time    2023-08-12 19:24:03
# name              Magic longbow
# id                          859
# Name: 722962, dtype: object high                        1250
# high_time    2023-08-12 19:11:28
# name               Magic longbow
# id                           859
# Name: 317794, dtype: object Magic longbow 12.5 225000.0
# low                         155
# low_time    2023-08-12 19:24:21
# name                 Rune knife
# id                          868
# Name: 723252, dtype: object high                         179
# high_time    2023-08-12 19:14:36
# name                  Rune knife
# id                           868
# Name: 467476, dtype: object Rune knife 22.210000000000008 244310.0000000001
# low                         775
# low_time    2023-08-12 19:24:36
# name                       Ruby
# id                         1603
# Name: 723664, dtype: object high                         800
# high_time    2023-08-12 19:23:10
# name                        Ruby
# id                          1603
# Name: 348207, dtype: object Ruby 17.0 221000.0
# low                        1101
# low_time    2023-08-12 19:22:37
# name              Ruby necklace
# id                         1660
# Name: 670945, dtype: object high                        1125
# high_time    2023-08-12 19:24:32
# name               Ruby necklace
# id                          1660
# Name: 356762, dtype: object Ruby necklace 12.75 229500.0
# low                         149
# low_time    2023-08-12 19:24:30
# name            Gold amulet (u)
# id                         1673
# Name: 723460, dtype: object high                         162
# high_time    2023-08-12 19:22:50
# name             Gold amulet (u)
# id                          1673
# Name: 341999, dtype: object Gold amulet (u) 11.379999999999995 204839.9999999999
# low                        1769
# low_time    2023-08-12 19:24:16
# name                    Coconut
# id                         5974
# Name: 723174, dtype: object high                        1843
# high_time    2023-08-12 19:22:44
# name                     Coconut
# id                          5974
# Name: 1304, dtype: object Coconut 55.569999999999936 611269.9999999993
# low                        9085
# low_time    2023-08-12 19:24:28
# name          Saradomin brew(4)
# id                         6685
# Name: 723413, dtype: object high                        9292
# high_time    2023-08-12 19:24:31
# name           Saradomin brew(4)
# id                          6685
# Name: 356744, dtype: object Saradomin brew(4) 114.07999999999993 228159.99999999985
# low                        1992
# low_time    2023-08-12 19:24:27
# name             Mahogany plank
# id                         8782
# Name: 723379, dtype: object high                        2028
# high_time    2023-08-12 19:24:30
# name              Mahogany plank
# id                          8782
# Name: 356715, dtype: object Mahogany plank 15.720000000000027 204360.00000000035
# low                        1024
# low_time    2023-08-12 19:24:28
# name           Dragon arrowtips
# id                        11237
# Name: 723418, dtype: object high                        1062
# high_time    2023-08-12 19:23:42
# name            Dragon arrowtips
# id                         11237
# Name: 356005, dtype: object Dragon arrowtips 27.38000000000011 273800.0000000011
# low                        3170
# low_time    2023-08-12 19:22:37
# name           Black chinchompa
# id                        11959
# Name: 671030, dtype: object high                        3231
# high_time    2023-08-12 19:21:55
# name            Black chinchompa
# id                         11959
# Name: 1026, dtype: object Black chinchompa 28.690000000000055 315590.0000000006
# low                          14266
# low_time       2023-08-12 19:24:31
# name        Super combat potion(4)
# id                           12695
# Name: 723505, dtype: object high                          14549
# high_time       2023-08-12 19:24:27
# name         Super combat potion(4)
# id                            12695
# Name: 356636, dtype: object Super combat potion(4) 137.51000000000022 275020.00000000047
# low                          6868
# low_time      2023-08-12 19:24:34
# name        Superior dragon bones
# id                          22124
# Name: 723609, dtype: object high                          7000
# high_time      2023-08-12 19:24:34
# name         Superior dragon bones
# id                           22124
# Name: 356835, dtype: object Superior dragon bones 62.0 465000.0
# low                         472
# low_time    2023-08-12 19:23:15
# name          Amethyst dart tip
# id                        25853
# Name: 67694, dtype: object high                         500
# high_time    2023-08-12 19:22:53
# name           Amethyst dart tip
# id                         25853
# Name: 343145, dtype: object Amethyst dart tip 23.0 253000.0
